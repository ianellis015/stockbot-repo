# %% [markdown]
# ## Libraries/Dependencies ##

# %%
import pandas as pd
import matplotlib as plt
import sklearn as sklearn
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Yahoo Fincance DataFrame ##

# %%
import yfinance as yf

sp500_tickers = yf.download("^GSPC").index.tolist()
# data = yf.download(sp500_tickers, start='2023-01-01')
# print(sp500_tickers)
# Filter data for yesterday's date
# yesterday_data = data.loc[pd.Timestamp.now().date() - pd.Timedelta(days=1)]
# print(yesterday_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
print(data.describe())
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  285.000000  285.000000  285.000000  285.000000  285.000000
# mean   174.040211  175.620522  172.735509  174.323228  173.732803
# std     17.161901   16.897185   17.141106   16.964292   17.140623
# min    126.010002  127.769997  124.169998  125.019997  124.166649
# 25%    164.889999  166.289993  163.889999  165.229996  164.352737
# 50%    177.330002  179.380005  176.500000  177.789993  177.120560
# 75%    187.929993  189.250000  186.770004  188.039993  187.440811
# max    198.020004  199.619995  197.000000  198.110001  197.857529
#
#              Volume
# count  2.850000e+02
# mean   5.885050e+07
# std    1.732952e+07
# min    2.404830e+07
# 25%    4.755110e+07
# 50%    5.492910e+07
# 75%    6.555130e+07
# max    1.543573e+08

# %%
import matplotlib.pyplot as plt

# Plotting closing price
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Close Price', color='blue')
plt.title('AAPL Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate daily returns
data['Daily_Return'] = data['Close'].pct_change()

# Plotting daily returns
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Daily_Return'], label='Daily Return', color='green')
plt.title('AAPL Daily Returns')
plt.xlabel('Date')
plt.ylabel('Return')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate 50-day and 200-day moving averages
data['MA_50'] = data['Close'].rolling(window=50).mean()
data['MA_200'] = data['Close'].rolling(window=200).mean()

# Plotting moving averages
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label='Close Price', color='blue')
plt.plot(data.index, data['MA_50'], label='50-Day MA', color='red')
plt.plot(data.index, data['MA_200'], label='200-Day MA', color='green')
plt.title('AAPL Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# %%
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
#                   Open      High       Low     Close  Adj Close    Volume  \
# Open          1.000000  0.997482  0.997873  0.994424   0.994440 -0.320570
# High          0.997482  1.000000  0.997843  0.997687   0.997632 -0.293554
# Low           0.997873  0.997843  1.000000  0.997848   0.997757 -0.331525
# Close         0.994424  0.997687  0.997848  1.000000   0.999930 -0.313230
# Adj Close     0.994440  0.997632  0.997757  0.999930   1.000000 -0.313716
# Volume       -0.320570 -0.293554 -0.331525 -0.313230  -0.313716  1.000000
# Daily_Return -0.160009 -0.120374 -0.118344 -0.079736  -0.081010  0.087162
# MA_50         0.752908  0.757691  0.738927  0.745195   0.753329 -0.061548
# MA_200        0.477611  0.481667  0.453680  0.472502   0.481238 -0.027672
#
#               Daily_Return     MA_50    MA_200
# Open             -0.160009  0.752908  0.477611
# High             -0.120374  0.757691  0.481667
# Low              -0.118344  0.738927  0.453680
# ...

# %%
import pandas as pd

# Sample dataset representing investors and their risk tolerance levels
risk_tolerance_data = {
    'Investor_ID': [1, 2, 3, 4, 5],
    'Risk_Tolerance': ['low', 'low', 'moderate', 'moderate', 'high']
}

# Create a DataFrame from the sample dataset
tolerance_df = pd.data(risk_tolerance_data)

# Define numerical values for risk tolerance levels
risk_tolerance_mapping = {
    'low': 1,
    'moderate': 3,
    'high': 5
}

# Add a new column to the DataFrame for numerical risk tolerance values
investors_df['Risk_Tolerance_Numeric'] = investors_df['Risk_Tolerance'].map(risk_tolerance_mapping)

# Print the DataFrame to verify
print("Investors DataFrame with Risk Tolerance Variables:")
print(investors_df)
